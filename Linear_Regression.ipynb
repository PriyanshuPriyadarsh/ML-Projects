# %% [markdown]
# ## Linear Regression:-
# * Housing Price Prediction

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv('Housing.csv')

# %%
df.head()
# Out:
#       price  area
# 0  13300000  7420
# 1  12250000  8960
# 2  12250000  9960
# 3  12215000  7500
# 4  11410000  7420

# %%
# %matplotlib inline
plt.xlabel('Area')
plt.ylabel('Price(million $)')
plt.scatter(df.area,df.price,color='red',marker='*')
plt.plot(df.area,lreg.predict(df[['area']]),color='blue')
plt.title('Linear Regression')
plt.legend(["Predicted Price", "Linear Line"], loc="upper right")

# %%
df['area'].mean()
# Out:
# 5150.54128440367

# %%
lreg = linear_model.LinearRegression()
lreg.fit(df[['area']], df['price'])
# Out:
# LinearRegression()

# %%
print("Intercept:", lreg.intercept_)
print("Coefficient:", lreg.coef_)
# Out:
# Intercept: 2387308.4823964303
# Coefficient: [461.97489427]

# %%
lreg.predict([[3300]])
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3911825.63349662])

# %%
lreg.predict(df[['area']])
# Out:
# array([5815162.19790048, 6526603.53508057, 6988578.42935335,
#        5852120.18944231, 5815162.19790048, 5852120.18944231,
#        6351053.07525691, 9871301.76961552, 6129305.12600598,
#        5043664.12446493, 8485377.08679717, 5159157.84803313,
#        5413244.03988316, 4004220.61235117, 5990712.65772414,
#        5159157.84803313, 5436342.7845968 , 6314095.08371509,
#        4512392.99605123, 5353187.3036277 , 4383040.02565485,
#        5692738.8509182 , 6106206.38129234, 4493914.00028032,
#        6452687.55199692, 5408624.29094043, 5159157.84803313,
#        6487335.66906738, 6060008.89186506, 4928170.40089674,
#        5840570.81708549, 5621132.74230591, 4641745.96644761,
#        5140678.85226222, 5547216.75922227, 5621132.74230591,
#        5843804.6413454 , 6545082.53085148, 5159157.84803313,
#        5159157.84803313, 5413244.03988316, 5325468.80997133,
#        5380905.79728407, 5159157.84803313, 5159157.84803313,
# ...

# %% [markdown]
# #### checking value:y=mx+c

# %%
461.97489427*3300+2387308.4823964303
# Out:
# 3911825.6334874304

# %% [markdown]
# #### Reading area and predicting prices

# %%
d=pd.read_csv('area.csv')

# %%
d
# Out:
#     area
# 0   6000
# 1   6550
# 2   3500
# 3   7800
# 4   6000
# 5   6600
# 6   8500
# 7   4600
# 8   6420
# 9   4320
# 10  7155
# 11  8050

# %%
p = lreg.predict(d[['area']])

# %%
p
# Out:
# array([5159157.84803313, 5413244.03988316, 4004220.61235117,
#        5990712.65772414, 5159157.84803313, 5436342.7845968 ,
#        6314095.08371509, 4512392.99605123, 5353187.3036277 ,
#        4383040.02565485, 5692738.8509182 , 6106206.38129234])

# %%
d['price']=p

# %%
d
# Out:
#     area         price
# 0   6000  5.159158e+06
# 1   6550  5.413244e+06
# 2   3500  4.004221e+06
# 3   7800  5.990713e+06
# 4   6000  5.159158e+06
# 5   6600  5.436343e+06
# 6   8500  6.314095e+06
# 7   4600  4.512393e+06
# 8   6420  5.353187e+06
# 9   4320  4.383040e+06
# 10  7155  5.692739e+06
# 11  8050  6.106206e+06

# %%
d.to_csv('prediction.csv',index=False)
